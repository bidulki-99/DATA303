# %% [markdown]
# Variational Autoencoders (VAEs) - Model A
# ======
#
# The VAE implemented here uses the setup found in most VAE papers: a multivariate Normal distribution for the conditional distribution of the latent vectors given and input image ($q_{\phi}(z | x_i)$ in the slides) and a multivariate Bernoulli distribution for the conditional distribution of images given the latent vector ($p_{\theta}(x | z)$ in the slides). Using a Bernoulli distribution, the reconstruction loss (negative log likelihood of a data point in the output distribution) reduces to the pixel-wise binary cross-entropy. See the [original VAE paper](https://arxiv.org/pdf/1312.6114.pdf), Appendix C.1 for details.
#
# This code is from CreativeAI: Deep Learning for Graphics Tutorial [[Link]](https://github.com/smartgeometry-ucl/dl4g)

# %%
# !python --version
# Out:
# Python 3.9.16

# %%
# This is for colab users to mount google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/data303-main
# Out:
# /content/gdrive/MyDrive/data303-main

# %%
# install pytorch (http://pytorch.org/) if run from Google Colaboratory
import sys
# %matplotlib inline
import os

import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# Hyperparameters
# -----

# %%
# 2-d latent space, parameter count in the same order of magnitude
# as in the original VAE paper (VAE paper has about 3x as many)
latent_dims = 2
num_epochs = 100
batch_size = 128
capacity = 64
learning_rate = 1e-3
variational_beta = 1
use_gpu = True
savepath='./vae_2d_100.pth'

# # 10-d latent space, for comparison with non-variational auto-encoder
# latent_dims = 10
# num_epochs = 100
# batch_size = 128
# capacity = 64
# learning_rate = 1e-3
# variational_beta = 1
# use_gpu = True

# %% [markdown]
# MNIST Data Loading
# -------------------
#
# MNIST images show digits from 0-9 in 28x28 grayscale images. We do not center them at 0, because we will be using a binary cross-entropy loss that treats pixel values as probabilities in [0,1]. We create both a training set and a test set.

# %%
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST

img_transform = transforms.Compose([
    transforms.ToTensor()
])

train_dataset = MNIST(root='./data/MNIST', download=True, train=True, transform=img_transform)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = MNIST(root='./data/MNIST', download=True, train=False, transform=img_transform)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# VAE Definition
# -----------------------
# We use a convolutional encoder and decoder, which generally gives better performance than fully connected versions that have the same number of parameters.
#
# In convolution layers, we increase the channels as we approach the bottleneck, but note that the total number of features still decreases, since the channels increase by a factor of 2 in each convolution, but the spatial size decreases by a factor of 4.
#
# Kernel size 4 is used to avoid biasing problems described here: https://distill.pub/2016/deconv-checkerboard/

# %%
class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()
        c = capacity
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=c, kernel_size=4, stride=2, padding=1) # out: c x 14 x 14
        self.conv2 = nn.Conv2d(in_channels=c, out_channels=c*2, kernel_size=4, stride=2, padding=1) # out: c x 7 x 7
        self.fc_mu = nn.Linear(in_features=c*2*7*7, out_features=latent_dims)
        self.fc_logvar = nn.Linear(in_features=c*2*7*7, out_features=latent_dims)
            
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = x.view(x.size(0), -1) # flatten batch of multi-channel feature maps to a batch of feature vectors
        x_mu = self.fc_mu(x)
        x_logvar = self.fc_logvar(x)
        return x_mu, x_logvar

class Decoder(nn.Module):
    def __init__(self):
        super(Decoder, self).__init__()
        c = capacity
        self.fc = nn.Linear(in_features=latent_dims, out_features=c*2*7*7)
        self.conv2 = nn.ConvTranspose2d(in_channels=c*2, out_channels=c, kernel_size=4, stride=2, padding=1)
        self.conv1 = nn.ConvTranspose2d(in_channels=c, out_channels=1, kernel_size=4, stride=2, padding=1)
            
    def forward(self, x):
        x = self.fc(x)
        x = x.view(x.size(0), capacity*2, 7, 7) # unflatten batch of feature vectors to a batch of multi-channel feature maps
        x = F.relu(self.conv2(x))
        x = torch.sigmoid(self.conv1(x)) # last layer before output is sigmoid, since we are using BCE as reconstruction loss
        return x
    
class VariationalAutoencoder(nn.Module):
    def __init__(self):
        super(VariationalAutoencoder, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
    
    def forward(self, x):
        latent_mu, latent_logvar = self.encoder(x)
        latent = self.latent_sample(latent_mu, latent_logvar)
        x_recon = self.decoder(latent)
        return x_recon, latent_mu, latent_logvar
    
    def latent_sample(self, mu, logvar):
        if self.training:
            # the reparameterization trick
            std = logvar.mul(0.5).exp_()
            eps = torch.empty_like(std).normal_()
            return eps.mul(std).add_(mu)
        else:
            return mu
    
def vae_loss(recon_x, x, mu, logvar):
    # recon_x is the probability of a multivariate Bernoulli distribution p.
    # -log(p(x)) is then the pixel-wise binary cross-entropy.
    # Averaging or not averaging the binary cross-entropy over all pixels here
    # is a subtle detail with big effect on training, since it changes the weight
    # we need to pick for the other loss term by several orders of magnitude.
    # Not averaging is the direct implementation of the negative log likelihood,
    # but averaging makes the weight of the other loss term independent of the image resolution.
    recon_loss = F.binary_cross_entropy(recon_x.view(-1, 784), x.view(-1, 784), reduction='sum')
    
    # KL-divergence between the prior distribution over latent vectors
    # (the one we are going to sample from when generating new images)
    # and the distribution estimated by the generator for the given image.
    kldivergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    
    return recon_loss + variational_beta * kldivergence
    
    
vae = VariationalAutoencoder()

device = torch.device("cuda:0" if use_gpu and torch.cuda.is_available() else "cpu")
vae = vae.to(device)

num_params = sum(p.numel() for p in vae.parameters() if p.requires_grad)
print('Number of parameters: %d' % num_params)
# Out:
# Number of parameters: 308357

# %%
device = torch.device("cuda:0" if use_gpu and torch.cuda.is_available() else "cpu")

# %%
device = torch.device("cuda:0")

# %% [markdown]
# Train VAE
# --------

# %%
optimizer = torch.optim.Adam(params=vae.parameters(), lr=learning_rate, weight_decay=1e-5)

# set to training mode
vae.train()

train_loss_avg = []

print('Training ...')
for epoch in range(num_epochs):
    train_loss_avg.append(0)
    num_batches = 0
    
    for image_batch, _ in train_dataloader:
        
        image_batch = image_batch.to(device)

        # vae reconstruction
        image_batch_recon, latent_mu, latent_logvar = vae(image_batch)
        
        # reconstruction error
        loss = vae_loss(image_batch_recon, image_batch, latent_mu, latent_logvar)
        
        # backpropagation
        optimizer.zero_grad()
        loss.backward()
        
        # one step of the optmizer (using the gradients from backpropagation)
        optimizer.step()
        
        train_loss_avg[-1] += loss.item()
        num_batches += 1
        
    train_loss_avg[-1] /= num_batches
    print('Epoch [%d / %d] average reconstruction error: %f' % (epoch+1, num_epochs, train_loss_avg[-1]))
# Out:
# Training ...
# Epoch [1 / 100] average reconstruction error: 23772.966360
# Epoch [2 / 100] average reconstruction error: 21293.120775
# Epoch [3 / 100] average reconstruction error: 20662.029634
# Epoch [4 / 100] average reconstruction error: 20326.671604
# Epoch [5 / 100] average reconstruction error: 20094.135070
# Epoch [6 / 100] average reconstruction error: 19916.338547
# Epoch [7 / 100] average reconstruction error: 19791.257790
# Epoch [8 / 100] average reconstruction error: 19689.488331
# Epoch [9 / 100] average reconstruction error: 19593.827371
# Epoch [10 / 100] average reconstruction error: 19501.705649
# Epoch [11 / 100] average reconstruction error: 19439.317737
# Epoch [12 / 100] average reconstruction error: 19389.062313
# Epoch [13 / 100] average reconstruction error: 19322.568005
# Epoch [14 / 100] average reconstruction error: 19290.796202
# Epoch [15 / 100] average reconstruction error: 19240.090262
# Epoch [16 / 100] average reconstruction error: 19184.653622
# Epoch [17 / 100] average reconstruction error: 19155.831783
# Epoch [18 / 100] average reconstruction error: 19114.290972
# Epoch [19 / 100] average reconstruction error: 19083.543764
# Epoch [20 / 100] average reconstruction error: 19050.242933
# Epoch [21 / 100] average reconstruction error: 19017.060874
# Epoch [22 / 100] average reconstruction error: 18989.870500
# Epoch [23 / 100] average reconstruction error: 18968.703412
# Epoch [24 / 100] average reconstruction error: 18920.813198
# Epoch [25 / 100] average reconstruction error: 18910.659086
# Epoch [26 / 100] average reconstruction error: 18890.083724
# Epoch [27 / 100] average reconstruction error: 18862.846145
# Epoch [28 / 100] average reconstruction error: 18840.242475
# Epoch [29 / 100] average reconstruction error: 18822.367696
# Epoch [30 / 100] average reconstruction error: 18791.218161
# Epoch [31 / 100] average reconstruction error: 18780.834955
# Epoch [32 / 100] average reconstruction error: 18765.980812
# Epoch [33 / 100] average reconstruction error: 18749.783170
# Epoch [34 / 100] average reconstruction error: 18734.561186
# Epoch [35 / 100] average reconstruction error: 18730.281275
# Epoch [36 / 100] average reconstruction error: 18703.247739
# Epoch [37 / 100] average reconstruction error: 18698.027350
# Epoch [38 / 100] average reconstruction error: 18664.377588
# Epoch [39 / 100] average reconstruction error: 18662.460192
# Epoch [40 / 100] average reconstruction error: 18649.850711
# Epoch [41 / 100] average reconstruction error: 18627.814074
# Epoch [42 / 100] average reconstruction error: 18628.382065
# Epoch [43 / 100] average reconstruction error: 18608.038813
# Epoch [44 / 100] average reconstruction error: 18604.126537
# Epoch [45 / 100] average reconstruction error: 18586.007063
# Epoch [46 / 100] average reconstruction error: 18579.961352
# Epoch [47 / 100] average reconstruction error: 18570.443480
# Epoch [48 / 100] average reconstruction error: 18545.650530
# Epoch [49 / 100] average reconstruction error: 18546.703977
# Epoch [50 / 100] average reconstruction error: 18532.275112
# Epoch [51 / 100] average reconstruction error: 18506.849457
# Epoch [52 / 100] average reconstruction error: 18522.257513
# Epoch [53 / 100] average reconstruction error: 18514.529978
# Epoch [54 / 100] average reconstruction error: 18492.915462
# Epoch [55 / 100] average reconstruction error: 18491.899885
# Epoch [56 / 100] average reconstruction error: 18484.642072
# Epoch [57 / 100] average reconstruction error: 18467.510703
# Epoch [58 / 100] average reconstruction error: 18470.056795
# Epoch [59 / 100] average reconstruction error: 18451.824125
# Epoch [60 / 100] average reconstruction error: 18459.897630
# Epoch [61 / 100] average reconstruction error: 18443.811932
# Epoch [62 / 100] average reconstruction error: 18428.687948
# Epoch [63 / 100] average reconstruction error: 18434.212004
# Epoch [64 / 100] average reconstruction error: 18418.275299
# Epoch [65 / 100] average reconstruction error: 18411.387075
# Epoch [66 / 100] average reconstruction error: 18417.965666
# Epoch [67 / 100] average reconstruction error: 18399.379375
# Epoch [68 / 100] average reconstruction error: 18402.473400
# Epoch [69 / 100] average reconstruction error: 18387.874996
# Epoch [70 / 100] average reconstruction error: 18381.729884
# Epoch [71 / 100] average reconstruction error: 18375.380864
# Epoch [72 / 100] average reconstruction error: 18367.078331
# Epoch [73 / 100] average reconstruction error: 18366.178038
# Epoch [74 / 100] average reconstruction error: 18360.791455
# Epoch [75 / 100] average reconstruction error: 18364.592147
# Epoch [76 / 100] average reconstruction error: 18347.913250
# Epoch [77 / 100] average reconstruction error: 18340.946718
# Epoch [78 / 100] average reconstruction error: 18335.849439
# Epoch [79 / 100] average reconstruction error: 18337.259195
# Epoch [80 / 100] average reconstruction error: 18334.050398
# Epoch [81 / 100] average reconstruction error: 18315.099210
# Epoch [82 / 100] average reconstruction error: 18317.727504
# Epoch [83 / 100] average reconstruction error: 18302.535088
# Epoch [84 / 100] average reconstruction error: 18313.506240
# Epoch [85 / 100] average reconstruction error: 18310.682390
# Epoch [86 / 100] average reconstruction error: 18297.462970
# Epoch [87 / 100] average reconstruction error: 18287.775351
# Epoch [88 / 100] average reconstruction error: 18280.515046
# Epoch [89 / 100] average reconstruction error: 18289.347030
# Epoch [90 / 100] average reconstruction error: 18274.139307
# Epoch [91 / 100] average reconstruction error: 18272.548682
# Epoch [92 / 100] average reconstruction error: 18283.361872
# Epoch [93 / 100] average reconstruction error: 18265.674944
# Epoch [94 / 100] average reconstruction error: 18259.660169
# Epoch [95 / 100] average reconstruction error: 18260.660970
# Epoch [96 / 100] average reconstruction error: 18248.752107
# Epoch [97 / 100] average reconstruction error: 18247.866569
# Epoch [98 / 100] average reconstruction error: 18249.848156
# Epoch [99 / 100] average reconstruction error: 18255.207181
# Epoch [100 / 100] average reconstruction error: 18229.184883

# %% [markdown]
# Plot Training Curve
# --------------------

# %%
import matplotlib.pyplot as plt
plt.ion()

fig = plt.figure()
plt.plot(train_loss_avg)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# Evaluate on the Test Set
# -------------------------

# %%
# set to evaluation mode
vae.eval()

test_loss_avg, num_batches = 0, 0
for image_batch, _ in test_dataloader:
    
    with torch.no_grad():
    
        image_batch = image_batch.to(device)

        # vae reconstruction
        image_batch_recon, latent_mu, latent_logvar = vae(image_batch)

        # reconstruction error
        loss = vae_loss(image_batch_recon, image_batch, latent_mu, latent_logvar)

        test_loss_avg += loss.item()
        num_batches += 1
    
test_loss_avg /= num_batches
print('average reconstruction error: %f' % (test_loss_avg))
# Out:
# average reconstruction error: 18988.374413

# %%
torch.save(vae.state_dict(), savepath)

# %% [markdown]
# Visualize Reconstructions
# --------------------------

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

import torchvision.utils

vae.eval()

# This function takes as an input the images to reconstruct
# and the name of the model with which the reconstructions
# are performed
def to_img(x):
    x = x.clamp(0, 1)
    return x

def show_image(img):
    img = to_img(img)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

def visualise_output(images, model):

    with torch.no_grad():
    
        images = images.to(device)
        images, _, _ = model(images)
        images = images.cpu()
        images = to_img(images)
        np_imagegrid = torchvision.utils.make_grid(images[1:50], 10, 5).numpy()
        plt.imshow(np.transpose(np_imagegrid, (1, 2, 0)))
        plt.show()
 
images, labels = next(iter(test_dataloader)) # Bug Fix

# First visualise the original images
print('Original images')
show_image(torchvision.utils.make_grid(images[1:50],10,5))
plt.show()

# Reconstruct and visualise the images using the vae
print('VAE reconstruction:')
visualise_output(images, vae)
# Out:
# Original images
# VAE reconstruction:

# %% [markdown]
# Interpolate in Latent Space
# ----------------------------

# %%
# vae = VariationalAutoencoder()
# vae.load_state_dict(torch.load('./vae_2d_100.pth'))
# device = torch.device("cuda:0")
# vae.to(device)
vae.eval()

def interpolation(lambda1, model, img1, img2):
    
    with torch.no_grad():
    
        # latent vector of first image
        img1 = img1.to(device)
        latent_1, _ = model.encoder(img1)

        # latent vector of second image
        img2 = img2.to(device)
        latent_2, _ = model.encoder(img2)

        # interpolation of the two latent vectors
        inter_latent = lambda1* latent_1 + (1- lambda1) * latent_2

        # reconstruct interpolated image
        inter_image = model.decoder(inter_latent)
        inter_image = inter_image.cpu()

        return inter_image
    
# sort part of test set by digit
digits = [[] for _ in range(10)]
for img_batch, label_batch in test_dataloader:
    for i in range(img_batch.size(0)):
        digits[label_batch[i]].append(img_batch[i:i+1])
    if sum(len(d) for d in digits) >= 1000:
        break;

# interpolation lambdas
lambda_range=np.linspace(0,1,10)

fig, axs = plt.subplots(2,5, figsize=(15, 6))
fig.subplots_adjust(hspace = .5, wspace=.001)
axs = axs.ravel()

for ind,l in enumerate(lambda_range):
    inter_image=interpolation(1-float(l), vae, digits[0][0], digits[9][0])
   
    inter_image = to_img(inter_image)
    
    image = inter_image.numpy()
   
    axs[ind].imshow(image[0,0,:,:], cmap='gray')
    axs[ind].set_title('lambda_val='+str(round(l,1)))
plt.show()

# %% [markdown]
# Sample Latent Vector from Prior (VAE as Generator)
# -------------------------------------------------
#
# A VAE can generate new digits by drawing latent vectors from the prior distribution. Although the generated digits are not perfect, they are usually better than for a non-variational Autoencoder (compare results for the 10d VAE to the results for the autoencoder).
#
# Similar to autoencoders, the manifold of latent vectors that decode to valid digits is sparser in higher-dimensional latent spaces. Increasing the weight of the KL-divergence term in the loss (increasing `variational_beta`) makes the manifold less sparse at the cost of a lower-quality reconstruction. A pre-trained model with `variational_beta = 10` is available at `./pretrained/vae_10d_beta10.pth`.

# %%
vae.eval()

with torch.no_grad():

    # sample latent vectors from the normal distribution
    latent = torch.randn(128, latent_dims, device=device)

    # reconstruct images from the latent vectors
    img_recon = vae.decoder(latent)
    img_recon = img_recon.cpu()

    fig, ax = plt.subplots(figsize=(5, 5))
    show_image(torchvision.utils.make_grid(img_recon.data[:100],10,5))
    plt.show()

# %% [markdown]
# Sample from the distribution of training data in the latent space
# --------

# %%
vae = VariationalAutoencoder()
vae.load_state_dict(torch.load('./vae_2d_100.pth'))
device = torch.device("cuda:0")
vae.to(device)

for image_batch, _ in train_dataloader:
    
    image_batch = image_batch.to(device)

    # vae reconstruction
    image_batch_recon, latent_mu, latent_logvar = vae(image_batch)
    
    # reconstruction error
    loss = vae_loss(image_batch_recon, image_batch, latent_mu, latent_logvar)

    break

with torch.no_grad():

    img_recon = image_batch.to(device)
    latent, _ = vae.encoder(img_recon)
    img_recon = vae.decoder(latent)
    img_recon = img_recon.cpu()

    fig, ax = plt.subplots(figsize=(5, 5))
    show_image(torchvision.utils.make_grid(img_recon.data[:100],10,5))
    plt.show()

# %%
kldivergence = -0.5 * torch.sum(1 + latent_logvar - latent_mu.pow(2) - latent_logvar.exp())
print('KL Divergence: %d' % kldivergence)
# Out:
# KL Divergence: 846

# %% [markdown]
# Model B
# ======

# %% [markdown]
# Hyperparameters
# -----

# %%
latent_dims = 2
num_epochs = 100
batch_size = 128
capacity = 64
learning_rate = 1e-3
variational_beta = 1
use_gpu = True
savepath='./vae_2d_100_checker.pth'

# %% [markdown]
# MNIST Data Loading
# -------------------

# %%
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST

img_transform = transforms.Compose([
    transforms.ToTensor()
])

train_dataset = MNIST(root='./data/MNIST', download=True, train=True, transform=img_transform)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = MNIST(root='./data/MNIST', download=True, train=False, transform=img_transform)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# VAE Definition
# -----------------------

# %%
class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()
        c = capacity
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=c, kernel_size=4, stride=2, padding=1)
        self.conv2 = nn.Conv2d(in_channels=c, out_channels=c*2, kernel_size=4, stride=2, padding=1)
        self.fc_mu = nn.Linear(in_features=c*2*7*7, out_features=latent_dims)
        self.fc_logvar = nn.Linear(in_features=c*2*7*7, out_features=latent_dims)
            
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = x.view(x.size(0), -1)
        x_mu = self.fc_mu(x)
        x_logvar = self.fc_logvar(x)
        return x_mu, x_logvar

class Decoder(nn.Module):
    def __init__(self):
        super(Decoder, self).__init__()
        c = capacity
        self.fc = nn.Linear(in_features=latent_dims, out_features=c*2*7*7)
        self.conv2 = nn.ConvTranspose2d(in_channels=c*2, out_channels=c, kernel_size=3, stride=2, padding=1, output_padding=1)
        self.conv1 = nn.ConvTranspose2d(in_channels=c, out_channels=1, kernel_size=3, stride=2, padding=1, output_padding=1)
            
    def forward(self, x):
        x = self.fc(x)
        x = x.view(x.size(0), capacity*2, 7, 7) # unflatten batch of feature vectors to a batch of multi-channel feature maps
        x = F.relu(self.conv2(x))
        x = torch.sigmoid(self.conv1(x)) # last layer before output is sigmoid, since we are using BCE as reconstruction loss
        return x
    
class VariationalAutoencoder(nn.Module):
    def __init__(self):
        super(VariationalAutoencoder, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
    
    def forward(self, x):
        latent_mu, latent_logvar = self.encoder(x)
        latent = self.latent_sample(latent_mu, latent_logvar)
        x_recon = self.decoder(latent)
        return x_recon, latent_mu, latent_logvar
    
    def latent_sample(self, mu, logvar):
        if self.training:
            # the reparameterization trick
            std = logvar.mul(0.5).exp_()
            eps = torch.empty_like(std).normal_()
            return eps.mul(std).add_(mu)
        else:
            return mu
    
def vae_loss(recon_x, x, mu, logvar):
    recon_loss = F.binary_cross_entropy(recon_x.view(-1, 784), x.view(-1, 784), reduction='sum')
    kldivergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    
    return recon_loss + variational_beta * kldivergence
    
    
vae = VariationalAutoencoder()

device = torch.device("cuda:0" if use_gpu and torch.cuda.is_available() else "cpu")
vae = vae.to(device)

num_params = sum(p.numel() for p in vae.parameters() if p.requires_grad)
print('Number of parameters: %d' % num_params)
# Out:
# Number of parameters: 250565

# %%
device = torch.device("cuda:0" if use_gpu and torch.cuda.is_available() else "cpu")

# %%
device = torch.device("cuda:0")

# %% [markdown]
# Train VAE
# --------

# %%
optimizer = torch.optim.Adam(params=vae.parameters(), lr=learning_rate, weight_decay=1e-5)

vae.train()

train_loss_avg = []

print('Training ...')
for epoch in range(num_epochs):
    train_loss_avg.append(0)
    num_batches = 0
    
    for image_batch, _ in train_dataloader:
        
        image_batch = image_batch.to(device)

        image_batch_recon, latent_mu, latent_logvar = vae(image_batch)
        
        loss = vae_loss(image_batch_recon, image_batch, latent_mu, latent_logvar)
        
        optimizer.zero_grad()
        loss.backward()
        
        optimizer.step()
        
        train_loss_avg[-1] += loss.item()
        num_batches += 1
        
    train_loss_avg[-1] /= num_batches
    print('Epoch [%d / %d] average reconstruction error: %f' % (epoch+1, num_epochs, train_loss_avg[-1]))
# Out:
# Training ...
# Epoch [1 / 100] average reconstruction error: 24943.422945
# Epoch [2 / 100] average reconstruction error: 22038.829204
# Epoch [3 / 100] average reconstruction error: 21387.266466
# Epoch [4 / 100] average reconstruction error: 20911.628506
# Epoch [5 / 100] average reconstruction error: 20547.282785
# Epoch [6 / 100] average reconstruction error: 20293.135821
# Epoch [7 / 100] average reconstruction error: 20113.328519
# Epoch [8 / 100] average reconstruction error: 19988.950060
# Epoch [9 / 100] average reconstruction error: 19880.743187
# Epoch [10 / 100] average reconstruction error: 19787.003810
# Epoch [11 / 100] average reconstruction error: 19727.436582
# Epoch [12 / 100] average reconstruction error: 19661.415951
# Epoch [13 / 100] average reconstruction error: 19602.237342
# Epoch [14 / 100] average reconstruction error: 19553.680958
# Epoch [15 / 100] average reconstruction error: 19502.266044
# Epoch [16 / 100] average reconstruction error: 19455.409906
# Epoch [17 / 100] average reconstruction error: 19418.738646
# Epoch [18 / 100] average reconstruction error: 19380.113206
# Epoch [19 / 100] average reconstruction error: 19342.788465
# Epoch [20 / 100] average reconstruction error: 19309.999355
# Epoch [21 / 100] average reconstruction error: 19274.579876
# Epoch [22 / 100] average reconstruction error: 19244.367662
# Epoch [23 / 100] average reconstruction error: 19219.537865
# Epoch [24 / 100] average reconstruction error: 19187.386259
# Epoch [25 / 100] average reconstruction error: 19164.762795
# Epoch [26 / 100] average reconstruction error: 19140.191918
# Epoch [27 / 100] average reconstruction error: 19114.268349
# Epoch [28 / 100] average reconstruction error: 19096.109952
# Epoch [29 / 100] average reconstruction error: 19070.899974
# Epoch [30 / 100] average reconstruction error: 19050.810253
# Epoch [31 / 100] average reconstruction error: 19030.319902
# Epoch [32 / 100] average reconstruction error: 19014.349026
# Epoch [33 / 100] average reconstruction error: 18994.437304
# Epoch [34 / 100] average reconstruction error: 18975.214304
# Epoch [35 / 100] average reconstruction error: 18959.863335
# Epoch [36 / 100] average reconstruction error: 18946.190217
# Epoch [37 / 100] average reconstruction error: 18930.942672
# Epoch [38 / 100] average reconstruction error: 18910.187567
# Epoch [39 / 100] average reconstruction error: 18888.907785
# Epoch [40 / 100] average reconstruction error: 18883.149855
# Epoch [41 / 100] average reconstruction error: 18875.552432
# Epoch [42 / 100] average reconstruction error: 18860.528862
# Epoch [43 / 100] average reconstruction error: 18834.826901
# Epoch [44 / 100] average reconstruction error: 18841.860522
# Epoch [45 / 100] average reconstruction error: 18811.388230
# Epoch [46 / 100] average reconstruction error: 18805.516037
# Epoch [47 / 100] average reconstruction error: 18790.172023
# Epoch [48 / 100] average reconstruction error: 18782.752611
# Epoch [49 / 100] average reconstruction error: 18778.063914
# Epoch [50 / 100] average reconstruction error: 18766.376062
# Epoch [51 / 100] average reconstruction error: 18759.545076
# Epoch [52 / 100] average reconstruction error: 18752.229038
# Epoch [53 / 100] average reconstruction error: 18727.422720
# Epoch [54 / 100] average reconstruction error: 18714.706228
# Epoch [55 / 100] average reconstruction error: 18718.423083
# Epoch [56 / 100] average reconstruction error: 18710.107005
# Epoch [57 / 100] average reconstruction error: 18700.629660
# Epoch [58 / 100] average reconstruction error: 18692.846480
# Epoch [59 / 100] average reconstruction error: 18676.942949
# Epoch [60 / 100] average reconstruction error: 18672.850750
# Epoch [61 / 100] average reconstruction error: 18672.356035
# Epoch [62 / 100] average reconstruction error: 18659.452417
# Epoch [63 / 100] average reconstruction error: 18642.776702
# Epoch [64 / 100] average reconstruction error: 18633.163967
# Epoch [65 / 100] average reconstruction error: 18631.093023
# Epoch [66 / 100] average reconstruction error: 18626.596596
# Epoch [67 / 100] average reconstruction error: 18616.070666
# Epoch [68 / 100] average reconstruction error: 18608.065986
# Epoch [69 / 100] average reconstruction error: 18604.418643
# Epoch [70 / 100] average reconstruction error: 18593.169358
# Epoch [71 / 100] average reconstruction error: 18595.143711
# Epoch [72 / 100] average reconstruction error: 18579.081821
# Epoch [73 / 100] average reconstruction error: 18586.637718
# Epoch [74 / 100] average reconstruction error: 18568.424984
# Epoch [75 / 100] average reconstruction error: 18568.075041
# Epoch [76 / 100] average reconstruction error: 18564.252109
# Epoch [77 / 100] average reconstruction error: 18552.845249
# Epoch [78 / 100] average reconstruction error: 18547.935853
# Epoch [79 / 100] average reconstruction error: 18543.372345
# Epoch [80 / 100] average reconstruction error: 18536.869055
# Epoch [81 / 100] average reconstruction error: 18523.145431
# Epoch [82 / 100] average reconstruction error: 18524.754827
# Epoch [83 / 100] average reconstruction error: 18522.843259
# Epoch [84 / 100] average reconstruction error: 18515.537057
# Epoch [85 / 100] average reconstruction error: 18505.603130
# Epoch [86 / 100] average reconstruction error: 18496.405053
# Epoch [87 / 100] average reconstruction error: 18492.549440
# Epoch [88 / 100] average reconstruction error: 18502.382511
# Epoch [89 / 100] average reconstruction error: 18503.114776
# Epoch [90 / 100] average reconstruction error: 18476.057705
# Epoch [91 / 100] average reconstruction error: 18479.729752
# Epoch [92 / 100] average reconstruction error: 18473.334659
# Epoch [93 / 100] average reconstruction error: 18474.342769
# Epoch [94 / 100] average reconstruction error: 18468.081773
# Epoch [95 / 100] average reconstruction error: 18457.413296
# Epoch [96 / 100] average reconstruction error: 18450.661497
# Epoch [97 / 100] average reconstruction error: 18447.271880
# Epoch [98 / 100] average reconstruction error: 18443.534392
# Epoch [99 / 100] average reconstruction error: 18440.580382
# Epoch [100 / 100] average reconstruction error: 18436.275024

# %% [markdown]
# Plot Training Curve
# --------------------

# %%
import matplotlib.pyplot as plt
plt.ion()

fig = plt.figure()
plt.plot(train_loss_avg)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# Evaluate on the Test Set
# -------------------------

# %%
vae.eval()

test_loss_avg, num_batches = 0, 0
for image_batch, _ in test_dataloader:
    
    with torch.no_grad():
    
        image_batch = image_batch.to(device)

        image_batch_recon, latent_mu, latent_logvar = vae(image_batch)

        loss = vae_loss(image_batch_recon, image_batch, latent_mu, latent_logvar)

        test_loss_avg += loss.item()
        num_batches += 1
    
test_loss_avg /= num_batches
print('average reconstruction error: %f' % (test_loss_avg))
# Out:
# average reconstruction error: 19385.497398

# %%
torch.save(vae.state_dict(), savepath)

# %% [markdown]
# Visualize Reconstructions and Check Checkerboard Artifacts
# --------------------------

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

import torchvision.utils

vae.eval()

def to_img(x):
    x = x.clamp(0, 1)
    return x

def show_image(img):
    img = to_img(img)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

def visualise_output(images, model):

    with torch.no_grad():
    
        images = images.to(device)
        images, _, _ = model(images)
        images = images.cpu()
        images = to_img(images)
        np_imagegrid = torchvision.utils.make_grid(images[1:5], 2, 2).numpy()
        plt.imshow(np.transpose(np_imagegrid, (1, 2, 0)))
        plt.show()
 
images, labels = next(iter(test_dataloader))

print('VAE reconstruction:')
visualise_output(images, vae)
# Out:
# VAE reconstruction:

# %% [markdown]
# # Model C

# %% [markdown]
# Hyperparameters
# ---------------

# %%
latent_dims = 10
num_epochs = 100
batch_size = 128
capacity = 64
learning_rate = 1e-3
variational_beta = 1
use_gpu = True

# %% [markdown]
# MNIST Data Loading
# -------------------

# %%
img_transform = transforms.Compose([
    transforms.ToTensor()
])

train_dataset = MNIST(root='./data/MNIST', download=True, train=True, transform=img_transform)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = MNIST(root='./data/MNIST', download=True, train=False, transform=img_transform)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# VAE Definition
# -----------------------

# %%
class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()
        c = capacity
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=c, kernel_size=3, stride=2, padding=1)
        self.conv2 = nn.Conv2d(in_channels=c, out_channels=c*2, kernel_size=3, stride=2, padding=1)
        self.fc_mu = nn.Linear(in_features=c*2*7*7, out_features=latent_dims)
        self.fc_logvar = nn.Linear(in_features=c*2*7*7, out_features=latent_dims)
            
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = x.view(x.size(0), -1)
        x_mu = self.fc_mu(x)
        x_logvar = self.fc_logvar(x)
        return x_mu, x_logvar

class Decoder(nn.Module):
    def __init__(self):
        super(Decoder, self).__init__()
        c = capacity
        self.fc = nn.Linear(in_features=latent_dims, out_features=c*2*7*7)
        self.conv2 = nn.ConvTranspose2d(in_channels=c*2, out_channels=c, kernel_size=3, stride=2, padding=1, output_padding=1)
        self.conv1 = nn.ConvTranspose2d(in_channels=c, out_channels=1, kernel_size=3, stride=2, padding=1, output_padding=1)
            
    def forward(self, x):
        x = self.fc(x)
        x = x.view(x.size(0), capacity*2, 7, 7)
        x = F.relu(self.conv2(x))
        x = torch.sigmoid(self.conv1(x))
        return x

class VariationalAutoencoder(nn.Module):
    def __init__(self):
        super(VariationalAutoencoder, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
    
    def forward(self, x):
        latent_mu, latent_logvar = self.encoder(x)
        latent = self.latent_sample(latent_mu, latent_logvar)
        x_recon = self.decoder(latent)
        return x_recon, latent_mu, latent_logvar
    
    def latent_sample(self, mu, logvar):
        if self.training:
            std = logvar.mul(0.5).exp_()
            eps = torch.empty_like(std).normal_()
            return eps.mul(std).add_(mu)
        else:
            return mu

def vae_loss(recon_x, x, mu, logvar):
    recon_loss = F.binary_cross_entropy(recon_x.view(-1, 784), x.view(-1, 784), reduction='sum')
    kldivergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    
    return recon_loss + variational_beta * kldivergence

# %%
vae = VariationalAutoencoder()

device = torch.device("cuda:0" if use_gpu and torch.cuda.is_available() else "cpu")
vae = vae.to(device)

num_params = sum(p.numel() for p in vae.parameters() if p.requires_grad)
print('Number of parameters: %d' % num_params)
# Out:
# Number of parameters: 343317

# %%
device = torch.device("cuda:0" if use_gpu and torch.cuda.is_available() else "cpu")

# %%
device = torch.device("cuda:0")

# %% [markdown]
# Train VAE
# ------

# %%
optimizer = torch.optim.Adam(params=vae.parameters(), lr=learning_rate, weight_decay=1e-5)

# set to training mode
vae.train()

train_loss_avg = []

print('Training ...')
for epoch in range(num_epochs):
    train_loss_avg.append(0)
    num_batches = 0
    
    for image_batch, _ in train_dataloader:
        
        image_batch = image_batch.to(device)

        # vae reconstruction
        image_batch_recon, latent_mu, latent_logvar = vae(image_batch)
        
        # reconstruction error
        loss = vae_loss(image_batch_recon, image_batch, latent_mu, latent_logvar)
        
        # backpropagation
        optimizer.zero_grad()
        loss.backward()
        
        # one step of the optmizer (using the gradients from backpropagation)
        optimizer.step()
        
        train_loss_avg[-1] += loss.item()
        num_batches += 1
        
    train_loss_avg[-1] /= num_batches
    print('Epoch [%d / %d] average reconstruction error: %f' % (epoch+1, num_epochs, train_loss_avg[-1]))
# Out:
# Training ...
# Epoch [1 / 100] average reconstruction error: 19588.082342
# Epoch [2 / 100] average reconstruction error: 15449.266614
# Epoch [3 / 100] average reconstruction error: 14765.588138
# Epoch [4 / 100] average reconstruction error: 14422.404982
# Epoch [5 / 100] average reconstruction error: 14199.722309
# Epoch [6 / 100] average reconstruction error: 14045.618476
# Epoch [7 / 100] average reconstruction error: 13924.806778
# Epoch [8 / 100] average reconstruction error: 13820.820998
# Epoch [9 / 100] average reconstruction error: 13743.522334
# Epoch [10 / 100] average reconstruction error: 13681.760482
# Epoch [11 / 100] average reconstruction error: 13620.967288
# Epoch [12 / 100] average reconstruction error: 13568.092671
# Epoch [13 / 100] average reconstruction error: 13536.823615
# Epoch [14 / 100] average reconstruction error: 13495.794345
# Epoch [15 / 100] average reconstruction error: 13463.990757
# Epoch [16 / 100] average reconstruction error: 13435.459830
# Epoch [17 / 100] average reconstruction error: 13403.703544
# Epoch [18 / 100] average reconstruction error: 13379.998963
# Epoch [19 / 100] average reconstruction error: 13356.379106
# Epoch [20 / 100] average reconstruction error: 13333.427764
# Epoch [21 / 100] average reconstruction error: 13309.323244
# Epoch [22 / 100] average reconstruction error: 13296.566015
# Epoch [23 / 100] average reconstruction error: 13277.388374
# Epoch [24 / 100] average reconstruction error: 13260.852016
# Epoch [25 / 100] average reconstruction error: 13250.455819
# Epoch [26 / 100] average reconstruction error: 13231.327242
# Epoch [27 / 100] average reconstruction error: 13218.860131
# Epoch [28 / 100] average reconstruction error: 13211.141479
# Epoch [29 / 100] average reconstruction error: 13189.376749
# Epoch [30 / 100] average reconstruction error: 13179.903379
# Epoch [31 / 100] average reconstruction error: 13178.054017
# Epoch [32 / 100] average reconstruction error: 13161.151550
# Epoch [33 / 100] average reconstruction error: 13152.130037
# Epoch [34 / 100] average reconstruction error: 13141.072039
# Epoch [35 / 100] average reconstruction error: 13129.782025
# Epoch [36 / 100] average reconstruction error: 13121.020243
# Epoch [37 / 100] average reconstruction error: 13117.986178
# Epoch [38 / 100] average reconstruction error: 13111.172885
# Epoch [39 / 100] average reconstruction error: 13095.004945
# Epoch [40 / 100] average reconstruction error: 13090.499865
# Epoch [41 / 100] average reconstruction error: 13084.950468
# Epoch [42 / 100] average reconstruction error: 13072.920680
# Epoch [43 / 100] average reconstruction error: 13070.105871
# Epoch [44 / 100] average reconstruction error: 13063.718602
# Epoch [45 / 100] average reconstruction error: 13054.466403
# Epoch [46 / 100] average reconstruction error: 13052.150005
# Epoch [47 / 100] average reconstruction error: 13047.568070
# Epoch [48 / 100] average reconstruction error: 13039.825160
# Epoch [49 / 100] average reconstruction error: 13036.622953
# Epoch [50 / 100] average reconstruction error: 13027.342840
# Epoch [51 / 100] average reconstruction error: 13021.443942
# Epoch [52 / 100] average reconstruction error: 13020.114187
# Epoch [53 / 100] average reconstruction error: 13014.143988
# Epoch [54 / 100] average reconstruction error: 13008.082514
# Epoch [55 / 100] average reconstruction error: 13001.638395
# Epoch [56 / 100] average reconstruction error: 12997.232976
# Epoch [57 / 100] average reconstruction error: 12995.360889
# Epoch [58 / 100] average reconstruction error: 12994.078506
# Epoch [59 / 100] average reconstruction error: 12986.276652
# Epoch [60 / 100] average reconstruction error: 12979.145649
# Epoch [61 / 100] average reconstruction error: 12975.553090
# Epoch [62 / 100] average reconstruction error: 12976.512227
# Epoch [63 / 100] average reconstruction error: 12965.514253
# Epoch [64 / 100] average reconstruction error: 12968.836092
# Epoch [65 / 100] average reconstruction error: 12962.270926
# Epoch [66 / 100] average reconstruction error: 12957.914202
# Epoch [67 / 100] average reconstruction error: 12954.541969
# Epoch [68 / 100] average reconstruction error: 12950.961706
# Epoch [69 / 100] average reconstruction error: 12951.989472
# Epoch [70 / 100] average reconstruction error: 12942.745405
# Epoch [71 / 100] average reconstruction error: 12942.460148
# Epoch [72 / 100] average reconstruction error: 12936.720570
# Epoch [73 / 100] average reconstruction error: 12932.248709
# Epoch [74 / 100] average reconstruction error: 12930.692464
# Epoch [75 / 100] average reconstruction error: 12928.037378
# Epoch [76 / 100] average reconstruction error: 12926.934406
# Epoch [77 / 100] average reconstruction error: 12920.816639
# Epoch [78 / 100] average reconstruction error: 12917.057925
# Epoch [79 / 100] average reconstruction error: 12913.868077
# Epoch [80 / 100] average reconstruction error: 12913.687723
# Epoch [81 / 100] average reconstruction error: 12910.808261
# Epoch [82 / 100] average reconstruction error: 12911.294622
# Epoch [83 / 100] average reconstruction error: 12904.309075
# Epoch [84 / 100] average reconstruction error: 12908.705665
# Epoch [85 / 100] average reconstruction error: 12902.678555
# Epoch [86 / 100] average reconstruction error: 12899.393780
# Epoch [87 / 100] average reconstruction error: 12898.883968
# Epoch [88 / 100] average reconstruction error: 12893.826946
# Epoch [89 / 100] average reconstruction error: 12892.646162
# Epoch [90 / 100] average reconstruction error: 12893.052497
# Epoch [91 / 100] average reconstruction error: 12888.591632
# Epoch [92 / 100] average reconstruction error: 12887.244007
# Epoch [93 / 100] average reconstruction error: 12881.244084
# Epoch [94 / 100] average reconstruction error: 12877.737055
# Epoch [95 / 100] average reconstruction error: 12880.895577
# Epoch [96 / 100] average reconstruction error: 12878.265436
# Epoch [97 / 100] average reconstruction error: 12869.687096
# Epoch [98 / 100] average reconstruction error: 12867.729388
# Epoch [99 / 100] average reconstruction error: 12870.952602
# Epoch [100 / 100] average reconstruction error: 12868.087014

# %% [markdown]
# Plot Training Curve
# --------------------

# %%
plt.ion()

fig = plt.figure()
plt.plot(train_loss_avg)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# Evaluate on the Test Set
# -------------------------

# %%
# set to evaluation mode
vae.eval()

test_loss_avg, num_batches = 0, 0
for image_batch, _ in test_dataloader:
    
    with torch.no_grad():
    
        image_batch = image_batch.to(device)

        # vae reconstruction
        image_batch_recon, latent_mu, latent_logvar = vae(image_batch)

        # reconstruction error
        loss = vae_loss(image_batch_recon, image_batch, latent_mu, latent_logvar)

        test_loss_avg += loss.item()
        num_batches += 1
    
test_loss_avg /= num_batches
print('average reconstruction error: %f' % (test_loss_avg))
# Out:
# average reconstruction error: 12331.945211

# %%
savepath='./vae_10d_100.pth'
torch.save(vae.state_dict(), savepath)

# %% [markdown]
# Visualize Reconstructions
# -------------------------

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

import torchvision.utils

vae.eval()

# This function takes as an input the images to reconstruct
# and the name of the model with which the reconstructions
# are performed
def to_img(x):
    x = x.clamp(0, 1)
    return x

def show_image(img):
    img = to_img(img)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

def visualise_output(images, model):

    with torch.no_grad():
    
        images = images.to(device)
        images, _, _ = model(images)
        images = images.cpu()
        images = to_img(images)
        np_imagegrid = torchvision.utils.make_grid(images[1:50], 10, 5).numpy()
        plt.imshow(np.transpose(np_imagegrid, (1, 2, 0)))
        plt.show()
 
images, labels = next(iter(test_dataloader))

print('Original images')
show_image(torchvision.utils.make_grid(images[1:50],10,5))
plt.show()

print('VAE reconstruction:')
visualise_output(images, vae)
# Out:
# Original images
# VAE reconstruction:

# %%
def visualise_output(images, model):

    with torch.no_grad():
    
        images = images.to(device)
        images, _, _ = model(images)
        images = images.cpu()
        images = to_img(images)
        np_imagegrid = torchvision.utils.make_grid(images[1:5], 2, 2).numpy()
        plt.imshow(np.transpose(np_imagegrid, (1, 2, 0)))
        plt.show()
 
images, labels = next(iter(test_dataloader))

print('VAE reconstruction:')
visualise_output(images, vae)
# Out:
# VAE reconstruction:
